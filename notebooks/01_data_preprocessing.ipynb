# %% [markdown]
# # 01 — Data preprocessing
#
# Load the Melbourne wastewater treatment plant CSV, clean (drop redundant columns, move target to last), check for NaNs, and show clean dataframe head and shape.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from src.data import load_csv, clean_and_prepare
from src.config import RAW_DIR, DEFAULT_CSV_NAME

path = RAW_DIR / DEFAULT_CSV_NAME
if not path.exists():
    path = Path("../data/raw/Data-Melbourne_F_fixed.csv")  # or your path
df = load_csv(path)
print("Raw head:")
df.head()

# %%
df_clean = clean_and_prepare(df)
nan_info = df_clean.isna().sum()
print("Columns with NaN:", nan_info[nan_info > 0].to_dict() or "None")
print("\nClean shape:", df_clean.shape)
df_clean.head()
