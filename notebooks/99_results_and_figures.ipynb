# %% [markdown]
# # 99 — Results and figures
#
# Aggregate results from experiments (e.g. from `results/`) and reproduce key figures.

# %%
import sys
from pathlib import Path
import pandas as pd
sys.path.insert(0, str(Path.cwd().parent))

results_dir = Path("../results")
figures_dir = Path("../figures")
if results_dir.exists():
    for f in results_dir.glob("*.csv"):
        print(f.name)
        display(pd.read_csv(f).head())
else:
    print("No results/ directory or CSV files yet. Run notebooks 03–05 and save summaries to results/.")
